# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/cleaned_data.csv")
df.head()
# Out:
#    customerid  tenure  monthlycharges  totalcharges  contract  paymentmethod  \
# 0           0       6              64          1540         1              1
# 1           1      21             113          1753         0              2
# 2           2      27              31          1455         2              1
# 3           3      53              29          7150         0              2
# 4           4      16             185          1023         1              2
#
#    paperlessbilling  seniorcitizen  churn
# 0                 0              1      0
# 1                 1              1      0
# 2                 0              1      0
# 3                 0              1      0
# 4                 0              1      0

# %%
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)
df.describe()
# Out:
# Shape: (500, 9)
#
# Columns:
#  Index(['customerid', 'tenure', 'monthlycharges', 'totalcharges', 'contract',
#        'paymentmethod', 'paperlessbilling', 'seniorcitizen', 'churn'],
#       dtype='object')
#        customerid      tenure  monthlycharges  totalcharges    contract  \
# count  500.000000  500.000000      500.000000    500.000000  500.000000
# mean   249.500000   36.532000      113.636000   4237.882000    0.948000
# std    144.481833   20.667057       51.799903   2260.619837    0.791549
# min      0.000000    1.000000       20.000000    159.000000    0.000000
# 25%    124.750000   19.000000       67.000000   2237.250000    0.000000
# 50%    249.500000   37.000000      115.000000   4182.500000    1.000000
# 75%    374.250000   54.000000      158.000000   6266.750000    2.000000
# max    499.000000   71.000000      199.000000   7992.000000    2.000000
#
#        paymentmethod  paperlessbilling  seniorcitizen       churn
# count      500.00000        500.000000     500.000000  500.000000
# mean         1.00800          0.486000       0.498000    0.106000
# std          0.80326          0.500305       0.500497    0.308146
# min          0.00000          0.000000       0.000000    0.000000
# 25%          0.00000          0.000000       0.000000    0.000000
# 50%          1.00000          0.000000       0.000000    0.000000
# 75%          2.00000          1.000000       1.000000    0.000000
# max          2.00000          1.000000       1.000000    1.000000

# %%
for col in df.columns:
    print(f"{col}:", df[col].nunique())
# Out:
# customerid: 500
# tenure: 71
# monthlycharges: 166
# totalcharges: 490
# contract: 3
# paymentmethod: 3
# paperlessbilling: 2
# seniorcitizen: 2
# churn: 2

# %%
df['churn'].value_counts().plot(kind='bar')
plt.title("Churn vs Non-Churn")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()

# %%
df['churn'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Churn Percentage")
plt.ylabel("")
plt.show()

# %%
df.hist(figsize=(10,8))
plt.suptitle("Feature Distributions")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.title("Boxplot of Features")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
for col in df.columns:
    if col != 'churn':
        plt.figure()
        sns.boxplot(x='churn', y=col, data=df)
        plt.title(f"{col} vs Churn")
        plt.show()

# %%
df.groupby('churn').mean()
# Out:
#        customerid     tenure  monthlycharges  totalcharges  contract  \
# churn
# 0      249.212528  40.152125      111.722595   4234.577181  0.997763
# 1      251.924528   6.000000      129.773585   4265.754717  0.528302
#
#        paymentmethod  paperlessbilling  seniorcitizen
# churn
# 0           0.993289          0.483221       0.501119
# 1           1.132075          0.509434       0.471698

# %%
if 'usage' in df.columns:
    sns.histplot(df['usage'], kde=True)
    plt.title("Usage Distribution")
    plt.show()
